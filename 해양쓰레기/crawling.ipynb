# %% [markdown]
# # 원하는 측정소의 위,경도를 크롤링해오자

# %%
import os
os.getcwd()
os.chdir('D:\\jupyter_proj\\gongbig')

# %%
from selenium.webdriver import Chrome
from selenium import webdriver
import time
import sqlite3
from pandas.io import sql
import os
import pandas as pd
import re
from selenium.webdriver.common.keys import Keys
import time

# %%
def open_browser(location_list):
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized");
    browser = webdriver.Chrome('chromedriver', options=options)
    browser.get("https://www.google.com/maps/?hl=ko")
    time.sleep(4)
    print("클릭전")
    
    browser.find_element_by_xpath('//*[@id="searchboxinput"]').click()
    print("클릭함")
  
    df_list = []
    for i in location_list:
        length=len(i)
        print(i)
        time.sleep(2)
        browser.find_element_by_xpath('//*[@id="searchboxinput"]').send_keys(i)
        browser.find_element_by_xpath('//*[@id="searchbox-searchbutton"]').click()
        
        
        time.sleep(5)
        
        url=browser.current_url
        lilong=re.search(r'@.*,.*,',url).group(0)
        lilong=lilong[1:]
        latitude, longitude = lilong.split(",")[0:2]

        df = pd.DataFrame({
            '지역':[i],
            '위도':[latitude],
            '경도':[longitude]
            
        })
        df_list.append(df)
        print(i,'넣음')
        
        element=browser.find_element_by_xpath('//*[@id="searchboxinput"]')
        element.click()
       
        for i in range(len(i)+1):
            element.send_keys(Keys.BACKSPACE)
            element.send_keys(Keys.DELETE)
        
        
    return pd.concat(df_list)

# %%
trash_19=pd.read_csv("./trash_19.csv",encoding='cp949')

# %%
where=list(set(trash_19['지역']))

# %%
d=open_browser(where)
# Out:
# 클릭전
# 클릭함
# 태안 안면도 바람아래해변
# 태안 안면도 바람아래해변 넣음
# click
# 마산 봉암갯벌
# 마산 봉암갯벌 넣음
# click
# 포항 구룡포 대보해변
# 포항 구룡포 대보해변 넣음
# click
# 해남 송평해변
# 해남 송평해변 넣음
# click
# 인천 영종도 용유해변
# 인천 영종도 용유해변 넣음
# click
# 해남 묵동리
# 해남 묵동리 넣음
# click
# 거제 두모몽돌해변
# 거제 두모몽돌해변 넣음
# click
# 강화 여차리갯벌
# 강화 여차리갯벌 넣음
# click
# 여수 백야도해변
# 여수 백야도해변 넣음
# click
# 영광 백바위해변
# 영광 백바위해변 넣음
# click
# 신안 임자도
# 신안 임자도 넣음
# click
# 부안 변산
# 부안 변산 넣음
# click
# 고흥 염포해변
# 고흥 염포해변 넣음
# click
# 사천 아두도
# 사천 아두도 넣음
# click
# 강릉 송정
# 강릉 송정 넣음
# click
# 울산 대왕암
# 울산 대왕암 넣음
# click
# 고흥 신흥
# 고흥 신흥 넣음
# click
# 인천 덕적도 서포리해변
# 인천 덕적도 서포리해변 넣음
# click
# 제주 김녕리해안
# 제주 김녕리해안 넣음
# click
# 영덕 고래불해변
# 영덕 고래불해변 넣음
# click
# 해남 예락해변
# 해남 예락해변 넣음
# click
# 보령 석대도
# 보령 석대도 넣음
# click
# 서천 다사항해변
# 서천 다사항해변 넣음
# click
# 인천 백령도 사곶해안
# 인천 백령도 사곶해안 넣음
# click
# 제주 사계리해안
# 제주 사계리해안 넣음
# click
# 태안 백리포
# 태안 백리포 넣음
# click
# 진도 하조도
# 진도 하조도 넣음
# click
# 동해 노봉해변
# 동해 노봉해변 넣음
# click
# 포항 칠포
# 포항 칠포 넣음
# click
# 울주 진하해변
# 울주 진하해변 넣음
# click
# 고창 동호해변
# 고창 동호해변 넣음
# click
# 속초 청초
# 속초 청초 넣음
# click
# 통영 망일봉
# 통영 망일봉 넣음
# click
# 신안 고장리해변
# 신안 고장리해변 넣음
# click
# 남해 유구해변
# 남해 유구해변 넣음
# click
# 안산 말부흥
# 안산 말부흥 넣음
# click
# 완도 신지도해변
# 완도 신지도해변 넣음
# click
# 부산 해양대
# 부산 해양대 넣음
# click
# 순천 반월
# 순천 반월 넣음
# click
# 울진 후정
# 울진 후정 넣음
# click

# %%
d
# Out:
#               장소          위도           경도
# 0  태안 안면도 바람아래해변  36.4120808  126.3724595
# 0        마산 봉암갯벌  35.2165697  128.6219662
# 0    포항 구룡포 대보해변  35.9780323  129.5084145
# 0        해남 송평해변  34.4355688  126.4668606
# 0    인천 영종도 용유해변  37.4459457  126.2822731
# 0         해남 묵동리  34.7073763  126.6547281
# 0      거제 두모몽돌해변  34.9786824   128.692105
# 0       강화 여차리갯벌   37.609325  126.3805603
# 0       여수 백야도해변  34.6394452  127.4660183
# 0       영광 백바위해변  35.2428313  126.3018846
# 0         신안 임자도   35.088985  126.0832425
# 0          부안 변산  35.6808324  126.5270116
# 0        고흥 염포해변  34.4326972  127.4879593
# 0         사천 아두도   34.969495  128.0409307
# 0          강릉 송정  37.8098203  128.9441192
# 0         울산 대왕암  35.4923951  129.4373716
# 0          고흥 신흥  34.6125698  127.1679495
# 0   인천 덕적도 서포리해변  37.3548871  126.1529082
# 0       제주 김녕리해안  33.5560664  126.7073854
# 0       영덕 고래불해변  36.5998357  129.4072196
# 0        해남 예락해변  34.5243277  126.3475906
# 0         보령 석대도  36.2392619   126.529536
# 0       서천 다사항해변  36.2898071  126.3353571
# 0    인천 백령도 사곶해안  37.9548078  124.6837074
# 0       제주 사계리해안  33.2302426  126.3028531
# 0         태안 백리포  36.8128896  126.1508039
# 0         진도 하조도  34.2999114  126.0466811
# 0        동해 노봉해변  37.5871271  129.0970246
# 0          포항 칠포  36.1323914  129.3946512
# 0        울주 진하해변   35.383396  129.3417054
# 0        고창 동호해변  35.5168293  126.4784999
# 0          속초 청초  38.1969847    128.57834
# 0         통영 망일봉  34.8486105  128.4353448
# 0       신안 고장리해변   34.845293  125.9407546
# 21                                      밧줄(꼬인 것, 어업용)   46   35.088985
# 22                                          농약용기, 살충제    1   34.845293
# 23                                     기타(일회용 위생장갑 등)    1   34.845293
# 24                스티로폼 식품용기(음식물포장용, 컵라면, 도시락, 과일포장 등)    1   34.845293
# 25                                                 어망    1   34.845293
# 26                                        음료수병, 병뚜껑 등    1   34.845293
# 27                                           스티로폼 어상자    1   34.845293
# 28                                            플라스틱 부표    2   34.845293
# 29                                  가짜미끼, 형광찌, 낚시 미끼통    2   34.845293
# 30                                        음료수병, 각종 뚜껑    3   34.845293
# 31                                        끈(노끈, 포장용끈)    3   34.845293
# 32                                   1회용품 접시·숟가락·빨대 등    3   34.845293
# 33                                                 파편    4   34.845293
# 34                                  포장지(라면봉지, 과자봉지 등)    6   34.845293
# 35                                               비닐봉지   10   34.845293
# 36                                      밧줄(꼬인 것, 어업용)   30   34.845293
# 37                                                라이터    1  35.4923951
# 38                                            플라스틱 부표    1  35.4923951
# 39                                      통발, 장어통발용 미끼통    1  35.4923951
# 40                                  가짜미끼, 형광찌, 낚시 미끼통    1  35.4923951
# 41                                               비닐봉지    1  35.4923951
# 42                                     기타(일회용 위생장갑 등)    1  35.4923951
# 43                                     기타(스폰지, 물휴지 등)    1  35.4923951
# 44                                      밧줄(꼬인 것, 어업용)    1  35.4923951
# 45                       옷, 천, 장갑, 양말, 이불 등(합성섬유만 해당)    1  35.4923951
# 46                                  타이어, 고무풍선, 고무장갑 등    1  35.4923951
# 47                                                낚싯줄    2  35.4923951
# 48   캔, 가스캔, 낚시바늘, 낚시추, 스프링 통발, 스프레이캔, 못, 철사, 폭죽 철심 등    2  35.4923951
# 49                     가전제품, 차량부품, 도자기, 타일, 건전지, 양초 등    2  35.4923951
#
#              경도
# 0   128.4353448
# 1   128.4353448
# 2   128.4353448
# 3   128.4353448
# 4   128.4353448
# 5   128.4353448
# 6   128.4353448
# 7   128.4353448
# 8   126.0832425
# 9   126.0832425
# 10  126.0832425
# 11  126.0832425
# 12  126.0832425
# 13  126.0832425
# 14  126.0832425
# 15  126.0832425
# 16  126.0832425
# 17  126.0832425
# 18  126.0832425
# 19  126.0832425
# 20  126.0832425
# 21  126.0832425
# 22  125.9407546
# 23  125.9407546
# 24  125.9407546
# 25  125.9407546
# 26  125.9407546
# 27  125.9407546
# 28  125.9407546
# 29  125.9407546
# 30  125.9407546
# 31  125.9407546
# 32  125.9407546
# 33  125.9407546
# 34  125.9407546
# 35  125.9407546
# 36  125.9407546
# 37  129.4373716
# 38  129.4373716
# 39  129.4373716
# 40  129.4373716
# 41  129.4373716
# 42  129.4373716
# 43  129.4373716
# 44  129.4373716
# 45  129.4373716
# 46  129.4373716
# 47  129.4373716
# 48  129.4373716
# 49  129.4373716
